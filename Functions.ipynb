# %%
# First function example: Add 1 to a and store as b

def add(a):
    """
    add 1 to a
    """
    b = a + 1
    print(a, "if you add one", b)
    return(b)

# %%
# Get a help on add function

help(add)
# Out:
# Help on function add in module __main__:
#
# add(a)
#     add 1 to a

# %%
# Call the function add()

add(1)
# Out:
# 1 if you add one 2
# 2

# %%
# Call the function add()

add(2)
# Out:
# 2 if you add one 3
# 3

# %%
# Define functions, one with return value None and other without return value
# The following two functions are equivalent:

def MJ():
    print('The BodyGuard')
    
def MJ1():
    print('The BodyGuard')
    return(None)

# %%
# See what functions returns are

print(MJ())
print(MJ1())
# Out:
# The BodyGuard
# None
# The BodyGuard
# None

# %%
#You will see below will return an error as integer alone is not considered while using a function.It either has to be in the form of tuple, list or a set.

sum(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 #You will see below will return an error as integer alone is not considered while using a function.It either has to be in the form of tuple, list or a set.
# ----> 3 sum(1,2)
#
# TypeError: 'int' object is not iterable

# %%
# Define a tuple
a = (1, 2)

# Pass the tuple to the sum function and store the result in a variable
c = sum(a)

# Print the result
print(f"The sum of the elements in the tuple {a} is {c}.")
# Out:
# The sum of the elements in the tuple (1, 2) is 3.

# %%
# Define a list
a = [1, 2]

# Pass the list to the sum function and store the result in a variable
c = sum(a)

# Print the result
print(f"The sum of the elements in the list {a} is {c}.")
# Out:
# The sum of the elements in the list [1, 2] is 3.

# %%
#Compare Two Strings Directly using in operator
# add string
string= "The BodyGuard is the best album"

# Define a funtion
def check_string(text):
    
# Use if else statement and 'in' operatore to compare the string
    if text in string:
        return 'String matched'
    else:
        return 'String not matched'

check_string("The BodyGuard is the best")
# Out:
# 'String matched'

# %%
# Example for setting param with default value

def isGoodRating(rating=4): 
    if(rating < 7):
        print("this album sucks it's rating is",rating)
        
    else:
        print("this album is good its rating is",rating)

# %%
# Test the value with default value and with input

isGoodRating()
isGoodRating(10)
# Out:
# this album sucks it's rating is 4
# this album is good its rating is 10

# %%
# Example of global variable

album = "The BodyGuard"
def printer1(album):
    internal_var1 = "Thriller"
    print(album, "is an album")
    
printer1(album )
# try runningthe following code
#printer1(internal_var1)
# Out:
# The BodyGuard is an album

# %%
printer1(internal_var1) #error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 printer1(internal_var1)
#
# NameError: name 'internal_var1' is not defined

# %%
album = "The BodyGuard"

def printer(album):
    global internal_var 
    internal_var= "Thriller"
    print(album,"is an album")

printer(album) 
printer(internal_var)
# Out:
# The BodyGuard is an album
# Thriller is an album

# %%
# When the number of arguments are unknown for a function, They can all be packed into a tuple as shown:def printAll(*args): # All the arguments are 'packed' into args which can be treated like a tuple
def printAll(*args): # All the arguments are 'packed' into args which can be treated like a tuple
    print("No of arguments:", len(args)) 
    for argument in args:
        print(argument)
#printAll with 3 arguments
printAll('Horsefeather','Adonis','Bone')
#printAll with 4 arguments
printAll('Sidecar','Long Island','Mudslide','Carriage')
# Out:
# No of arguments: 3
# Horsefeather
# Adonis
# Bone
# No of arguments: 4
# Sidecar
# Long Island
# Mudslide
# Carriage

# %%
def printDictionary(**args):
    for key in args:
        print(key + " : " + args[key])

printDictionary(Country='Canada',Province='Ontario',City='Toronto')
# Out:
# Country : Canada
# Province : Ontario
# City : Toronto

# %%
def addItems(list):
    list.append("Three")
    list.append("Four")

myList = ["One","Two"]

addItems(myList)

myList
# Out:
# ['One', 'Two', 'Three', 'Four']

# %%
def con(a, b):
    return(a + b)

# %%
con(2, 2)
# Out:
# 4

# %%
con(['a', 1], ['b', 1])
# Out:
# ['a', 1, 'b', 1]
