# %%
print("Hi there")
# Out:
# Hi there

# %%
# Check the Python Version

import sys
print(sys.version)
# Out:
# 3.9.12 (main, Apr  5 2022, 06:56:58)
# [GCC 7.5.0]

# %%
type(float(2))
# Out:
# float

# %%
int('1')
# Out:
# 1

# %%
type(int('1'))
# Out:
# int

# %%
print(float(True))
# Out:
# 1.0
